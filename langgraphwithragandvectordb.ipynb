# %% [markdown]
# <a href="https://colab.research.google.com/github/vishalc412/AIPOC/blob/Master/langgraphwithragandvectordb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langgraph langchain langchain_community langchain_groq langchain_huggingface langchainhub
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.7/148.7 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 44.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.7/109.7 kB 9.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 412.7/412.7 kB 20.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.7/44.7 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 77.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 14.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 37.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.0 MB/s eta 0:00:00
# ...

# %%
# !pip install duckduckgo_search
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 45.8 MB/s eta 0:00:00
# ...

# %%
from duckduckgo_search import DDGS

# %%
def searchduckduckgo(query):
    results = DDGS().text(query,max_results=5)
    for i, result in enumerate(results):
        print(f"{i+1}: {result['title']} - {result['href']}")

# %%
searchduckduckgo("who is shruti bhola, who works in wipro")
# Out:
# 1: Shruti Bhola - Hro - Wipro | LinkedIn - https://in.linkedin.com/in/shruti-bhola-b56883176
# 2: shruti Bhole - Project Engineering - Wipro | LinkedIn - https://in.linkedin.com/in/shruti-bhole-370a88287
# 3: 10+ "Shruti Bhola" profiles | LinkedIn - https://www.linkedin.com/pub/dir/shruti/bhola
# 4: Shruti Bhola on LinkedIn: I'm happy to share that I'm starting a new ... - https://www.linkedin.com/posts/shruti-bhola-b56883176_im-happy-to-share-that-im-starting-a-new-activity-6892536614401253376-CHGy
# 5: Shruti Bhola - Delhi, India | Professional Profile | LinkedIn - https://in.linkedin.com/in/shruti-bhola-33078048
